# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurahg22/Trabajo-analitica-RH/blob/main/Copia_de_Caso_RH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Cargar librerías

# %%
#### Cargar paquetes siempre al inicio
import pandas as pd ### para manejo de datos
import sqlite3 as sql #### para bases de datos sql
import sys ## saber ruta de la que carga paquetes

# %%
## Conectar el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
###Ruta directorio qué tiene paquetes
sys.path
sys.path.append('/content/drive/MyDrive/Trabajo-analitica-RH') ## este comanda agrega una ruta

# %%
import a_funciones as funciones  ###archivo de funciones propias

# %%
## todas las bases de datos se registran en una variable y se convierten en dataframe
data_general = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/data/general_data.csv")
manager_survey = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/data/manager_survey.csv")
retirement_info = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/data/retirement_info.csv")
employee_survey = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/data/employee_survey_data.csv")

# %%
# Configurar la opción para mostrar todas las columnas completas
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Comprender y Limpiar datos
#
# 1.   Verificar lectura correcta de los datos.
# 2.   Verificar Datos faltantes (eliminar variables si es necesario) (la imputación está la parte de modelado).
# 3. Tipos de variables (categoricas/numéricas/fechas)
# 4. Niveles en categorícas
# 5. Observaciones por categoría
# 6. Datos atípicos en numéricas

# %% [markdown]
# ### Base de datos 1

# %%
#Lectura de datos
data_general.sort_values(by=['EmployeeID'],ascending=1)
# Out:
#       Unnamed: 0  Age     BusinessTravel              Department  \
# 0              0   51      Travel_Rarely                   Sales
# 4410           0   51      Travel_Rarely                   Sales
# 4411           1   31  Travel_Frequently  Research & Development
# 1              1   31  Travel_Frequently  Research & Development
# 2              2   32  Travel_Frequently  Research & Development
# ...          ...  ...                ...                     ...
# 4407        4407   25      Travel_Rarely  Research & Development
# 8818        4408   42      Travel_Rarely                   Sales
# 4408        4408   42      Travel_Rarely                   Sales
# 4409        4409   40      Travel_Rarely  Research & Development
# 8819        4409   40      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
#Aplicar value_counts
data_general['Over18'].value_counts() # se aplica está función para ver la frecuencia de datos
# Out:
# Y    8820
# Name: Over18, dtype: int64

# %%
#Aplicar value_counts
data_general['StandardHours'].value_counts() # se aplica está función para ver la frecuencia de datos
# Out:
# 8    8820
# Name: StandardHours, dtype: int64

# %%
#Aplicar value_counts
data_general['EmployeeCount'].value_counts() # se aplica está función para ver la frecuencia de datos
# Out:
# 1    8820
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# Se observa que en estas 3 variables se repite continuamente un valor para todas las casillas de los datos, para el caso de Over18 se repite "Y", en StandardHours se repite "8" y en EmployeeCount se repite "1". Por la razón mencionada anteriormente se decide eliminar estas variables.

# %%
# Eliminar variable
data_general = data_general.drop(['Unnamed: 0', 'Over18', 'StandardHours', 'EmployeeCount'], axis=1) # Se elimina la variable Unnamed: 0 porque esta no aporta nada información pertinente, solo enumera.

# %%
##### resumen con información tablas faltantes y tipos de variables
data_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      8820 non-null   int64
#  1   BusinessTravel           8820 non-null   object
#  2   Department               8820 non-null   object
#  3   DistanceFromHome         8820 non-null   int64
#  4   Education                8820 non-null   int64
#  5   EducationField           8820 non-null   object
#  6   EmployeeID               8820 non-null   int64
#  7   Gender                   8820 non-null   object
#  8   JobLevel                 8820 non-null   int64
#  9   JobRole                  8820 non-null   object
#  10  MaritalStatus            8820 non-null   object
#  11  MonthlyIncome            8820 non-null   int64
#  12  NumCompaniesWorked       8782 non-null   float64
#  13  PercentSalaryHike        8820 non-null   int64
# ...

# %%
# Cambiar el tipo de dato de la variable fecha a formato fecha
data_general['InfoDate'] = pd.to_datetime(data_general['InfoDate'], format='%Y/%m/%d')
data_general['InfoDate']
# Out:
# 0      2015-12-31
# 1      2015-12-31
# 2      2015-12-31
# 3      2015-12-31
# 4      2015-12-31
#           ...
# 8815   2016-12-31
# 8816   2016-12-31
# 8817   2016-12-31
# 8818   2016-12-31
# 8819   2016-12-31
# Name: InfoDate, Length: 8820, dtype: datetime64[ns]

# %%
# verificamos los cambios
data_general.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   51      Travel_Rarely                   Sales                 6
# 1   31  Travel_Frequently  Research & Development                10
# 2   32  Travel_Frequently  Research & Development                17
# 3   38         Non-Travel  Research & Development                 2
# 4   32      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences           1  Female         1
# 1          1  Life Sciences           2  Female         1
# 2          4          Other           3    Male         4
# 3          5  Life Sciences           4    Male         3
# 4          1        Medical           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# ...

# %%
data_general.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         38
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears          18
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# InfoDate                    0
# dtype: int64

# %% [markdown]
# ### Base de datos 2

# %%
#Lectura de datos
manager_survey.sort_values(by=['EmployeeID'], ascending=1)
# Out:
#       Unnamed: 0  EmployeeID  JobInvolvement  PerformanceRating  SurveyDate
# 0              0           1               3                  3  2015-12-31
# 4410           0           1               3                  3  2016-12-31
# 4411           1           2               2                  4  2016-12-31
# 1              1           2               2                  4  2015-12-31
# 2              2           3               3                  3  2015-12-31
# ...          ...         ...             ...                ...         ...
# 4407        4407        4408               3                  4  2015-12-31
# 8818        4408        4409               2                  3  2016-12-31
# 4408        4408        4409               2                  3  2015-12-31
# 4409        4409        4410               4                  3  2015-12-31
# 8819        4409        4410               4                  3  2016-12-31
#
# [8820 rows x 5 columns]

# %%
# Eliminar variable
manager_survey = manager_survey.drop(['Unnamed: 0'], axis=1) # Se elimina la variable Unnamed: 0 porque esta no aporta nada información pertinente, solo enumera.

# %%
##### resumen con información tablas faltantes y tipos de variables
manager_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         8820 non-null   int64
#  1   JobInvolvement     8820 non-null   int64
#  2   PerformanceRating  8820 non-null   int64
#  3   SurveyDate         8820 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 275.8+ KB

# %%
manager_survey.isnull().sum()
# Out:
# EmployeeID           0
# JobInvolvement       0
# PerformanceRating    0
# SurveyDate           0
# dtype: int64

# %%
# Cambiar el tipo de dato de la variable fecha a formato fecha
manager_survey['SurveyDate'] = pd.to_datetime(manager_survey['SurveyDate'], format='%Y/%m/%d')
manager_survey['SurveyDate']
manager_survey.dtypes
# Out:
# EmployeeID                    int64
# JobInvolvement                int64
# PerformanceRating             int64
# SurveyDate           datetime64[ns]
# dtype: object

# %%
#Verificar los cambios
manager_survey.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating SurveyDate
# 0           1               3                  3 2015-12-31
# 1           2               2                  4 2015-12-31
# 2           3               3                  3 2015-12-31
# 3           4               2                  3 2015-12-31
# 4           5               3                  3 2015-12-31

# %% [markdown]
# En esta base de datos no se encuentran variables que eliminar, los datos que proporciona pueden ser utilizados posteriormente y no se observan valores nulos.

# %% [markdown]
# ### Base de datos 3

# %%
#Lectura de datos
retirement_info.sort_values(by=['EmployeeID'],ascending=1)
# Out:
#      Unnamed: 0.1  Unnamed: 0  EmployeeID Attrition retirementDate  \
# 0               0           0           2       Yes     2016-10-15
# 1               1           1           7       Yes     2016-07-20
# 2               2           2          14       Yes     2016-11-08
# 3               3           3          29       Yes     2016-10-15
# 4               4           4          31       Yes     2016-02-08
# ..            ...         ...         ...       ...            ...
# 706           706         706        4382       Yes     2015-04-18
# 707           707         707        4387       Yes     2015-09-16
# 708           708         708        4389       Yes     2015-05-24
# 709           709         709        4392       Yes     2015-02-26
# 710           710         710        4403       Yes     2015-01-26
#
#     retirementType resignationReason
# 0      Resignation            Others
# 1      Resignation            Stress
# 2      Resignation            Others
# ...

# %%
##### resumen con información tablas faltantes y tipos de variables
retirement_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       711 non-null    int64
#  1   Unnamed: 0         711 non-null    int64
#  2   EmployeeID         711 non-null    int64
#  3   Attrition          711 non-null    object
#  4   retirementDate     711 non-null    object
#  5   retirementType     711 non-null    object
#  6   resignationReason  641 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 39.0+ KB

# %%
#Aplicar value_counts
retirement_info['Attrition'].value_counts() # se aplica está función para ver la frecuencia de datos
# Out:
# Yes    711
# Name: Attrition, dtype: int64

# %%
# Eliminar variable
retirement_info = retirement_info.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1) # Se elimina la variable Unnamed: 0 porque esta no aporta nada información pertinente, solo enumera.

# %% [markdown]
# Se eliminaron tres variables en esta base de datos (dos por enumeración) y la otra "Attrition" debido a que solo era una respuesta para todos los empleados, esto no aporta información. Por otra parte se encuentras valores nulos en la variable "resignationReason", pero se considera valiosa, ya que, el motivo de renuncia podría explicar ciertas incertidumbres próximamente (consideración).

# %%
# Cambiar el tipo de dato de la variable fecha a formato fecha
retirement_info['retirementDate'] = pd.to_datetime(retirement_info['retirementDate'], format='%Y/%m/%d')
retirement_info.dtypes
# Out:
# EmployeeID                    int64
# Attrition                    object
# retirementDate       datetime64[ns]
# retirementType               object
# resignationReason            object
# dtype: object

# %%
#verificar los cambios
retirement_info.head()
# Out:
#    EmployeeID Attrition retirementDate retirementType resignationReason
# 0           2       Yes     2016-10-15    Resignation            Others
# 1           7       Yes     2016-07-20    Resignation            Stress
# 2          14       Yes     2016-11-08    Resignation            Others
# 3          29       Yes     2016-10-15    Resignation            Others
# 4          31       Yes     2016-02-08    Resignation            Salary

# %%
retirement_info.isnull().sum()
# Out:
# EmployeeID            0
# Attrition             0
# retirementDate        0
# retirementType        0
# resignationReason    70
# dtype: int64

# %% [markdown]
# ### Base de datos 4

# %%
#Lectura de datos
employee_survey.sort_values(by=['EmployeeID'],ascending=1)
# Out:
#       Unnamed: 0  EmployeeID  EnvironmentSatisfaction  JobSatisfaction  \
# 0              0           1                      3.0              4.0
# 4410           0           1                      3.0              4.0
# 4411           1           2                      3.0              2.0
# 1              1           2                      3.0              2.0
# 2              2           3                      2.0              2.0
# ...          ...         ...                      ...              ...
# 4407        4407        4408                      1.0              3.0
# 8818        4408        4409                      4.0              1.0
# 4408        4408        4409                      4.0              1.0
# 4409        4409        4410                      1.0              3.0
# 8819        4409        4410                      1.0              3.0
#
#       WorkLifeBalance  DateSurvey
# 0                 2.0  2015-12-31
# 4410              2.0  2016-12-31
# ...

# %%
##### resumen con información tablas faltantes y tipos de variables
employee_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               8820 non-null   int64
#  1   EmployeeID               8820 non-null   int64
#  2   EnvironmentSatisfaction  8770 non-null   float64
#  3   JobSatisfaction          8780 non-null   float64
#  4   WorkLifeBalance          8744 non-null   float64
#  5   DateSurvey               8820 non-null   object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 413.6+ KB

# %%
# Eliminar variable
employee_survey = employee_survey.drop(['Unnamed: 0'], axis=1) # Se elimina la variable Unnamed: 0 porque esta no aporta nada información pertinente, solo enumera.

# %%
# Cambiar el tipo de dato de la variable fecha a formato fecha
employee_survey['DateSurvey'] = pd.to_datetime(employee_survey['DateSurvey'], format='%Y/%m/%d')
employee_survey.dtypes
# Out:
# EmployeeID                          int64
# EnvironmentSatisfaction           float64
# JobSatisfaction                   float64
# WorkLifeBalance                   float64
# DateSurvey                 datetime64[ns]
# dtype: object

# %%
#verificar los cambios
employee_survey.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
#
#   DateSurvey
# 0 2015-12-31
# 1 2015-12-31
# 2 2015-12-31
# 3 2015-12-31
# 4 2015-12-31

# %%
employee_survey.isnull().sum()

# %% [markdown]
# #Consultas SQL Laura y Carlos

# %%
#### crear base de datos para manejo de datos ####
conn = sql.connect("/content/drive/MyDrive/Trabajo-analitica-RH/data/bd_empleados.csv") ### crea una base de datos con el nombre dentro de comillas, si existe crea una conexión.
cur=conn.cursor() ### ejecutar funciones  en BD

# %%
### Llevar tablas a base de datos
data_general.to_sql("data_general",conn,if_exists="replace")
employee_survey.to_sql("employee_survey",conn,if_exists="replace")
manager_survey.to_sql("manager_survey",conn,if_exists="replace")
retirement_info.to_sql("retirement_info",conn,if_exists="replace")

# %%
funciones.ejecutar_sql('Preprocesamiento.sql',cur)
cur.execute("Select name from sqlite_master where type='table'") ### consultar bases de datos
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-76-0d18cc21085d> in <cell line: 1>()
# ----> 1 funciones.ejecutar_sql('Preprocesamiento.sql',cur)
#       2 cur.execute("Select name from sqlite_master where type='table'") ### consultar bases de datos
#       3 cur.fetchall()
#
# /content/drive/MyDrive/Trabajo-analitica-RH/a_funciones.py in ejecutar_sql(nombre_archivo, cur)
#      13
#      14 def ejecutar_sql (nombre_archivo, cur):
# ---> 15   sql_file=open(nombre_archivo)
#      16   sql_as_string=sql_file.read()
#      17   sql_file.close
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Preprocesamiento.sql'

# %% [markdown]
# # Consultas SQL YUDY

# %%
conn.close()

# %%
#### crear base de datos para manejo de datos ####
conn = sql.connect("/content/drive/MyDrive/Trabajo-analitica-RH/data/bd_empleados.csv") ### crea una base de datos con el nombre dentro de comillas, si existe crea una conexión.
cur=conn.cursor() ### ejecutar funciones  en BD

# %%
data_general = pd.read_sql('SELECT * FROM data_general', con=conn)
employee_survey = pd.read_sql('SELECT * FROM employee_survey', con=conn)
manager_survey = pd.read_sql('SELECT * FROM manager_survey', con=conn)
retirement_info = pd.read_sql('SELECT * FROM retirement_info', con=conn)

# %%
# para ver las dimensiones de las tablas y hacerme una idea de como deberian quedar las dimensiones despues de hacer la union
print(data_general.shape)
print(employee_survey.shape)
print(manager_survey.shape)
print(retirement_info.shape)
# Out:
# (8820, 22)
# (8820, 6)
# (8820, 5)
# (711, 6)

# %%
# queria verificar si las fechas son las mismas
print(data_general['InfoDate'].unique())
print(employee_survey['DateSurvey'].unique())
print(manager_survey['SurveyDate'].unique())
#print(retirement_info['retirementDate'].unique())
# Out:
# ['2015-12-31 00:00:00' '2016-12-31 00:00:00']
# ['2015-12-31 00:00:00' '2016-12-31 00:00:00']
# ['2015-12-31 00:00:00' '2016-12-31 00:00:00']

# %%
# Definir la consulta SQL para unir las tablas
consulta_sql = """
CREATE TABLE IF NOT EXISTS data_final AS
SELECT gd.*,
  es.EnvironmentSatisfaction, es.JobSatisfaction, es.WorkLifeBalance,
  ms.JobInvolvement, ms.PerformanceRating,
  ri.Attrition, ri.retirementDate, ri.retirementType, ri.resignationReason
FROM data_general AS gd
LEFT JOIN employee_survey AS es
ON gd.EmployeeID = es.EmployeeID AND strftime('%Y', gd.InfoDate) = strftime('%Y', es.DateSurvey)
LEFT JOIN manager_survey AS ms
ON gd.EmployeeID = ms.EmployeeID AND strftime('%Y', gd.InfoDate) = strftime('%Y', ms.SurveyDate)
LEFT JOIN (
  SELECT *
  FROM retirement_info
  WHERE strftime('%Y', retirementDate) = '2016'
) AS ri
ON gd.EmployeeID = ri.EmployeeID AND strftime('%Y', gd.InfoDate) = '2015';

CREATE TABLE IF NOT EXISTS datos_2015 AS
SELECT *
FROM data_final
WHERE strftime('%Y', InfoDate) = '2015'
AND (strftime('%Y', retirementDate) = '2016' OR retirementDate IS NULL);

-- Crear tabla datos_2016 con la información deseada
CREATE TABLE IF NOT EXISTS datos_2016 AS
SELECT *,
       NULL AS Attrition,
       NULL AS retirementDate,
       NULL AS retirementType,
       NULL AS resignationReason
FROM data_final
WHERE strftime('%Y', InfoDate) = '2016';
"""

# Confirmar los cambios y cerrar la conexión a la base de datos
conn.commit()
conn.close()

# %%
#### crear base de datos para manejo de datos ####
conn = sql.connect("/content/drive/MyDrive/Trabajo-analitica-RH/data/bd_empleados.csv") ### crea una base de datos con el nombre dentro de comillas, si existe crea una conexión.
cur=conn.cursor() ### ejecutar funciones  en BD

# Cargar los datos en DataFrames de pandas
datos_2015 = pd.read_sql("SELECT * FROM datos_2015", conn)
datos_2016 = pd.read_sql("SELECT * FROM datos_2016", conn)

# Cerrar la conexión a la base de datos
conn.close()

# %%
# Exporta el DataFrame a un archivo CSV
datos_2015.to_csv('/content/drive/MyDrive/Trabajo-analitica-RH/data/df_2015', index=False)
datos_2016.to_csv('/content/drive/MyDrive/Trabajo-analitica-RH/data/df_2016', index=False)

# %%
df2015 = pd.read_csv("/content/drive/MyDrive/Trabajo-analitica-RH/data/df_2015")
df2015
# Out:
#       index  Age     BusinessTravel              Department  DistanceFromHome  \
# 0         0   51      Travel_Rarely                   Sales                 6
# 1         1   31  Travel_Frequently  Research & Development                10
# 2         2   32  Travel_Frequently  Research & Development                17
# 3         3   38         Non-Travel  Research & Development                 2
# 4         4   32      Travel_Rarely  Research & Development                10
# ...     ...  ...                ...                     ...               ...
# 4405   4405   42      Travel_Rarely  Research & Development                 5
# 4406   4406   29      Travel_Rarely  Research & Development                 2
# 4407   4407   25      Travel_Rarely  Research & Development                25
# 4408   4408   42      Travel_Rarely                   Sales                18
# 4409   4409   40      Travel_Rarely  Research & Development                28
#
# ...

# %%
df2015 = pd.read_csv("/content/drive/MyDrive/Trabajo-analitica-RH/data/df_2015")
datos_2016
# Out:
#       index  Age     BusinessTravel              Department  DistanceFromHome  \
# 0      4410   51      Travel_Rarely                   Sales                 6
# 1      4411   31  Travel_Frequently  Research & Development                10
# 2      4412   32  Travel_Frequently  Research & Development                17
# 3      4413   38         Non-Travel  Research & Development                 2
# 4      4414   32      Travel_Rarely  Research & Development                10
# ...     ...  ...                ...                     ...               ...
# 4405   8815   42      Travel_Rarely  Research & Development                 5
# 4406   8816   29      Travel_Rarely  Research & Development                 2
# 4407   8817   25      Travel_Rarely  Research & Development                25
# 4408   8818   42      Travel_Rarely                   Sales                18
# 4409   8819   40      Travel_Rarely  Research & Development                28
#
# ...

# %% [markdown]
# ### duda chicas

# %%
conn

# %%
### Llevar tablas a base de datos
df_action.to_sql("action",conn,if_exists="replace")
df_employees.to_sql("employee",conn,if_exists="replace")
df_performance.to_sql("performance",conn,if_exists="replace")

# %%
cur.execute("Select name from sqlite_master where type='table'") ### consultar bases de datos
cur.fetchall()
