# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurahg22/Trabajo-analitica-RH/blob/main/Caso_RH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### Cargar paquetes siempre al inicio
import pandas as pd ### para manejo de datos
import sqlite3 as sql #### para bases de datos sql
import sys ## saber ruta de la que carga paquetes

# %%
###Ruta directorio qué tiene paquetes
sys.path
sys.path.append('/content/drive/MyDrive/Caso-Recursos-Humanos') ## este comanda agrega una ruta

# %%
import a_funciones as funciones  ###archivo de funciones propias

# %%
data_general = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/general_data.csv")
manager_survey = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/manager_survey.csv")
retirement_info = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/retirement_info.csv")
employee_survey = pd.read_csv("https://raw.githubusercontent.com/Laurahg22/Trabajo-analitica-RH/main/employee_survey_data.csv")

# %%
data_general
# Out:
#       Unnamed: 0  Age     BusinessTravel              Department  \
# 0              0   51      Travel_Rarely                   Sales
# 1              1   31  Travel_Frequently  Research & Development
# 2              2   32  Travel_Frequently  Research & Development
# 3              3   38         Non-Travel  Research & Development
# 4              4   32      Travel_Rarely  Research & Development
# ...          ...  ...                ...                     ...
# 8815        4405   42      Travel_Rarely  Research & Development
# 8816        4406   29      Travel_Rarely  Research & Development
# 8817        4407   25      Travel_Rarely  Research & Development
# 8818        4408   42      Travel_Rarely                   Sales
# 8819        4409   40      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
data_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               8820 non-null   int64
#  1   Age                      8820 non-null   int64
#  2   BusinessTravel           8820 non-null   object
#  3   Department               8820 non-null   object
#  4   DistanceFromHome         8820 non-null   int64
#  5   Education                8820 non-null   int64
#  6   EducationField           8820 non-null   object
#  7   EmployeeCount            8820 non-null   int64
#  8   EmployeeID               8820 non-null   int64
#  9   Gender                   8820 non-null   object
#  10  JobLevel                 8820 non-null   int64
#  11  JobRole                  8820 non-null   object
#  12  MaritalStatus            8820 non-null   object
#  13  MonthlyIncome            8820 non-null   int64
# ...

# %%
# Configurar la opción para mostrar todas las columnas completas
pd.set_option('display.max_columns', None)

# %%
data_general = data_general.drop(['Unnamed: 0'], axis=1)

# %%
data_general
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
data_general['Over18'].value_counts()
# Out:
# Y    8820
# Name: Over18, dtype: int64

# %%
data_general['StandardHours'].value_counts()
# Out:
# 8    8820
# Name: StandardHours, dtype: int64

# %%
data_general['EmployeeCount'].value_counts()
# Out:
# 1    8820
# Name: EmployeeCount, dtype: int64

# %%
data_general = data_general.drop(['Over18', 'StandardHours','EmployeeCount'], axis=1)

# %%
data_general.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         38
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears          18
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# InfoDate                    0
# dtype: int64

# %%
data_general['NumCompaniesWorked'].value_counts()
# Out:
# 1.0    3116
# 0.0    1172
# 3.0     948
# 2.0     876
# 4.0     830
# 7.0     444
# 6.0     416
# 5.0     374
# 9.0     312
# 8.0     294
# Name: NumCompaniesWorked, dtype: int64

# %%
data_general[data_general['NumCompaniesWorked'].isnull()]
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 115    27      Travel_Rarely                   Sales                 2
# 210    52      Travel_Rarely                   Sales                 2
# 343    40  Travel_Frequently                   Sales                 9
# 476    22      Travel_Rarely  Research & Development                 8
# 647    29      Travel_Rarely  Research & Development                 3
# 799    29  Travel_Frequently  Research & Development                28
# 932    32      Travel_Rarely  Research & Development                 5
# 1103   26  Travel_Frequently                   Sales                16
# 1312   37      Travel_Rarely         Human Resources                 9
# 1521   31      Travel_Rarely  Research & Development                20
# 1711   33      Travel_Rarely                   Sales                13
# 1996   38      Travel_Rarely  Research & Development                 5
# ...
